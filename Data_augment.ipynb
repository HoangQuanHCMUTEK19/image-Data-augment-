# %% [markdown]
# <a href="https://colab.research.google.com/github/HoangQuanHCMUTEK19/image-Data-augment-/blob/main/Data_augment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
from tensorflow import keras
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt

# %%
img = load_img('image_609.jpg')
img = img_to_array(img)
data = np.expand_dims(img, 0)

# %%
#Phuong Phap zoom anh ngau nhien
myImageGen = ImageDataGenerator(zoom_range=[0.5,2.0])

# %%
gen = myImageGen.flow(data, batch_size=1)

# %%
for i in range(9):

	plt.subplot( 330 +  1 + i)
	myBatch = gen.next()
	image = myBatch[0].astype('uint8')
	plt.imshow(image)

plt.show()

# %%
#Dich trai phai 150 px 
myImageGen = ImageDataGenerator(width_shift_range=[-150,150])

# %%
gen = myImageGen.flow(data, batch_size=1)

# %%
for i in range(9):

	plt.subplot( 330 +  1 + i)
	myBatch = gen.next()
	image = myBatch[0].astype('uint8')
	plt.imshow(image)

plt.show()

# %%
#Dich tren xuong 
myImageGen = ImageDataGenerator(height_shift_range=[-200,200])

# %%
gen = myImageGen.flow(data, batch_size=1)

# %%
for i in range(9):

	plt.subplot( 330 +  1 + i)
	myBatch = gen.next()
	image = myBatch[0].astype('uint8')
	plt.imshow(image)

plt.show()

# %%
#Phuong phap tang giam do sang anh 
myImageGen = ImageDataGenerator(brightness_range=[0.2,2.0])

# %%
gen = myImageGen.flow(data, batch_size=1)

# %%
for i in range(9):

	plt.subplot( 330 +  1 + i)
	myBatch = gen.next()
	image = myBatch[0].astype('uint8')
	plt.imshow(image)

plt.show()

# %%
#Lat anh theo chieu ngang
myImageGen = ImageDataGenerator(horizontal_flip=True, vertical_flip=False)

# %%
gen = myImageGen.flow(data, batch_size=1)

# %%
for i in range(9):

	plt.subplot( 330 +  1 + i)
	myBatch = gen.next()
	image = myBatch[0].astype('uint8')
	plt.imshow(image)

plt.show()

# %%
#Lat anh theo chieu doc
myImageGen = ImageDataGenerator(horizontal_flip=False, vertical_flip=True)

# %%
gen = myImageGen.flow(data, batch_size=1)

# %%
for i in range(9):

	plt.subplot( 330 +  1 + i)
	myBatch = gen.next()
	image = myBatch[0].astype('uint8')
	plt.imshow(image)

plt.show()

# %%
#Xoay anh theo cac goc 
myImageGen = ImageDataGenerator(rotation_range=-30)

# %%
gen = myImageGen.flow(data, batch_size=1)

# %%
for i in range(9):

	plt.subplot( 330 +  1 + i)
	myBatch = gen.next()
	image = myBatch[0].astype('uint8')
	plt.imshow(image)

plt.show()

# %%
#làm méo ảnh 
myImageGen = ImageDataGenerator(shear_range=45)

# %%
gen = myImageGen.flow(data, batch_size=1)

# %%
for i in range(9):

	plt.subplot( 330 +  1 + i)
	myBatch = gen.next()
	image = myBatch[0].astype('uint8')
	plt.imshow(image)

plt.show()
